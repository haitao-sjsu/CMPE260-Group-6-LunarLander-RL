# %%
# %pip install swig
# %pip install "gymnasium[box2d]"
# Out:
# Requirement already satisfied: swig in /Users/longhaitao/.pyenv/versions/3.13.5/lib/python3.13/site-packages (4.4.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: gymnasium[box2d] in /Users/longhaitao/.pyenv/versions/3.13.5/lib/python3.13/site-packages (1.2.1)
# Requirement already satisfied: numpy>=1.21.0 in /Users/longhaitao/.pyenv/versions/3.13.5/lib/python3.13/site-packages (from gymnasium[box2d]) (2.3.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /Users/longhaitao/.pyenv/versions/3.13.5/lib/python3.13/site-packages (from gymnasium[box2d]) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /Users/longhaitao/.pyenv/versions/3.13.5/lib/python3.13/site-packages (from gymnasium[box2d]) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /Users/longhaitao/.pyenv/versions/3.13.5/lib/python3.13/site-packages (from gymnasium[box2d]) (0.0.4)
# Requirement already satisfied: box2d-py==2.3.5 in /Users/longhaitao/.pyenv/versions/3.13.5/lib/python3.13/site-packages (from gymnasium[box2d]) (2.3.5)
# Requirement already satisfied: pygame>=2.1.3 in /Users/longhaitao/.pyenv/versions/3.13.5/lib/python3.13/site-packages (from gymnasium[box2d]) (2.6.1)
# Requirement already satisfied: swig==4.* in /Users/longhaitao/.pyenv/versions/3.13.5/lib/python3.13/site-packages (from gymnasium[box2d]) (4.4.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from DQN import DQNConfig, train_loop

from plot import plot_avg_return

from evaluation import evaluate_policy, show_metrics

# %%
config = DQNConfig(MAX_ENV_STEPS=30_000)

# %%
result_dqn, agent_dqn = train_loop(config, variant='dqn')

plot_avg_return([result_dqn])

metrics_dqn = evaluate_policy(agent_dqn.select_deterministic_action, num_episodes=100, seed=0)

show_metrics("Vanilla DQN", metrics_dqn)
# Out:
# /Users/longhaitao/.pyenv/versions/3.13.5/lib/python3.13/site-packages/pygame/pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_stream, resource_exists
#   4%|▎         | 1096/30000 [00:00<00:02, 10936.70it/s]
# Episode:    1 | The latest 20 avg return: -158.88
#  36%|███▋      | 10900/30000 [00:03<00:07, 2515.53it/s]
# Episode:  100 | The latest 20 avg return: -134.77
#  67%|██████▋   | 20033/30000 [00:07<00:03, 2499.43it/s]
# Episode:  200 | The latest 20 avg return: -115.38
# 100%|██████████| 30000/30000 [00:11<00:00, 2593.72it/s]
# Episode:  300 | The latest 20 avg return: -68.95
# Vanilla DQN policy metrics:
# num_episodes: 100
# mean_return: -116.69999694824219
# std_return: 69.75569152832031
# min_return: -263.8113708496094
# max_return: 182.8794708251953
# solved_rate: 0.0
# success_rate: 0.03
# crash_rate: 0.3
# timeout_rate: 0.67
# other_terminal_rate: 0.0
# mean_episode_length: 893.81
# mean_main_engine_usage: 119.99
# mean_side_engine_usage: 624.91
# num_success_episodes: 3
# mean_final_abs_x_success: 0.21644394099712372
# mean_final_abs_vy_success: 0.0
# mean_final_abs_angle_success: 0.06722423434257507

# %%
result_double, agent_double = train_loop(config, variant='double')

plot_avg_return([result_double])

metrics_double = evaluate_policy(agent_double.select_deterministic_action, num_episodes=100, seed=0)

show_metrics("Double DQN", metrics_double)
# Out:
#  19%|█▉        | 95216/500000 [00:39<02:45, 2438.80it/s]
# Problem solved at episode 662

# %%
result_dueling, agent_dueling = train_loop(config, variant='dueling')

plot_avg_return([result_dueling])

metrics_dueling = evaluate_policy(agent_dueling.select_deterministic_action, num_episodes=100, seed=0)

show_metrics("Dueling DQN", metrics_dueling)
# Out:
#  38%|███▊      | 188200/500000 [01:32<02:32, 2044.48it/s]
# Problem solved at episode 770

# %%
plot_avg_return([result_dqn, result_double, result_dueling])
